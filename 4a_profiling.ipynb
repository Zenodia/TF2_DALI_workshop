# %%
# !nsys profile -y 10 -d 180 -w true -t "cudnn,cuda,osrt" --trace-fork-before-exec=true --force-overwrite true -o ./profile/out1 python BIG_DALI_train.py
# Out:
# **** collection configuration ****
# 	output_filename = /workspace/./profile/out1
# 	force-overwrite = true
# 	stop-on-exit = true
# 	export_sqlite = false
# 	stats = false
# 	capture-range = none
# 	stop-on-range-end = false
# 	delay = 10 seconds
# 	duration = 180 seconds
# 	kill = signal number 15
# 	inherit-environment = true
# 	show-output = true
# 	wait = all
# 	application command = python
# 	application arguments = BIG_DALI_train.py
# 	application working directory = /workspace
# 	NVTX profiler range trigger =
# 	NVTX profiler domain trigger =
# 	environment variables:
#
# 	application configuration
# 	    sample_cpu = true
# 	    backtrace_method = lbr
# 	    trace_cublas = false
# 	    trace_cuda = true
# 	    trace_cudnn = true
# 	    trace_nvtx = false
# 	    trace_mpi = false
# 	    trace_openacc = false
# 	    trace_vulkan = false
# 	    trace_opengl = false
# 	    trace_osrt = true
# 	    osrt-threshold = 0 nanoseconds
# 	    cudabacktrace = false
# ...

# %% [markdown]
# ## run nsight for detailed GPU utilization

# %%
# !nsys profile -y 10 -d 180 -w true -t "cudnn,cuda,osrt" --trace-fork-before-exec=true --force-overwrite true -o ./profile/out2 python SMALL_DALI_train.py
# Out:
# **** collection configuration ****
# 	output_filename = /workspace/./profile/out2
# 	force-overwrite = true
# 	stop-on-exit = true
# 	export_sqlite = false
# 	stats = false
# 	capture-range = none
# 	stop-on-range-end = false
# 	delay = 10 seconds
# 	duration = 180 seconds
# 	kill = signal number 15
# 	inherit-environment = true
# 	show-output = true
# 	wait = all
# 	application command = python
# 	application arguments = SMALL_DALI_train.py
# 	application working directory = /workspace
# 	NVTX profiler range trigger =
# 	NVTX profiler domain trigger =
# 	environment variables:
#
# 	application configuration
# 	    sample_cpu = true
# 	    backtrace_method = lbr
# 	    trace_cublas = false
# 	    trace_cuda = true
# 	    trace_cudnn = true
# 	    trace_nvtx = false
# 	    trace_mpi = false
# 	    trace_openacc = false
# 	    trace_vulkan = false
# 	    trace_opengl = false
# 	    trace_osrt = true
# 	    osrt-threshold = 0 nanoseconds
# 	    cudabacktrace = false
# ...
