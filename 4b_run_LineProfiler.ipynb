# %% [markdown]
# ## run line_profiler for data pipeline start with BIG image size
# ## 2525x2525x3 --> 800x800x3 --> 224x224x3

# %%
# !kernprof -l -v BIG_DALI_train_lineProfiler.py
# Out:
# 2020-05-18 12:54:57.953410: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.2
# 2020-05-18 12:54:59.891022: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-18 12:54:59.892426: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-DGXS-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:0f:00.0
# 2020-05-18 12:54:59.892454: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.2
# 2020-05-18 12:54:59.894326: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-18 12:54:59.896310: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# ...

# %% [markdown]
# ## run line_profiler for data pipeline start with archived augmented data with shape 224x224x3

# %%
# !kernprof -l -v SMALL_DALI_train_lineProfiler.py
# Out:
# 2020-05-18 13:04:46.915418: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.2
# 2020-05-18 13:04:49.144831: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-05-18 13:04:49.146234: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla V100-DGXS-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.53
# pciBusID: 0000:0f:00.0
# 2020-05-18 13:04:49.146262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.2
# 2020-05-18 13:04:49.148133: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-05-18 13:04:49.149959: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# ...
